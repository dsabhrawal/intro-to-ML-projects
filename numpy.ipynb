# %%
1+1
# Out:
# 2

# %%
4/3
# Out:
# 1.3333333333333333

# %%
4%3
# Out:
# 1

# %%
38*2+1
# Out:
# 77

# %%
a=12

# %%
b=13

# %%
a+b
# Out:
# 25

# %% [markdown]
# Strings

# %%
'deepak'
# Out:
# 'deepak'

# %%
'deepak"deepak'
# Out:
# 'deepak"deepak'

# %%
'hello'
# Out:
# 'hello'

# %%
a=10

# %%
b=13

# %%
'my maths numbers are {} and eng nums are  {}'.format(a,b)
# Out:
# 'my maths numbers are 10 and eng nums are  13'

# %%
mylist =[1,2,3]

# %%
mylist
# Out:
# [1, 2, 3, 'a']

# %%
mylist.append('a')

# %%
def square(a):
    return a**2;

# %%
square(34)
# Out:
# 1156

# %%
seq = [2,4,3,4]

# %%
map(lambda a: a**2, seq)

# %%
list(map(lambda a: a**2, seq))
# Out:
# [4, 16, 9, 16]

# %%
seq
# Out:
# [2, 4, 3, 4]
